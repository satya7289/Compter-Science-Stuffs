# %% [markdown]
# ### 1.Import the liberaries

# %%
# import liberaries
import warnings
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_openml
from sklearn.exceptions import ConvergenceWarning
from sklearn.neural_network import MLPClassifier

# %% [markdown]
# ### 2.Fetching online mnist_784 dataset

# %%
# Fetching the mnist_784 dataset
X, y = fetch_openml('mnist_784', version=1, return_X_y=True)

# %% [markdown]
# ### 3.normalize the dataset

# %%
# Normalize the intensity in range(0,1) from (0,255)
X = X / 255
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-6b647a10d5ac> in <module>
#       1 # Normalize the intensity in range(0,1) from (0,255)
# ----> 2 X = X / 255
#
# NameError: name 'X' is not defined

# %% [markdown]
# ### 4.Spliting the mnist dataset into training and testing dataset

# %%
# Spliting the mnist dataset for testing and training
X_train, X_test = X[:60000], X[60000:]
y_train, y_test = y[:60000], y[60000:]

# %% [markdown]
# ### 5. Training and testing dataset using MLPClassifier(Multi-layer Perceptron classifier).

# %%
# make a list of different batch sizes
batch_sizes = [200, 1000, 5000, 10000, 60000]
for b_s in batch_sizes:
    # Build model using MLPClassifier
    mlp = MLPClassifier(hidden_layer_sizes=(50,),max_iter=10,
                    solver='sgd',verbose=10, batch_size=b_s)

    # Remove unneccessary waring
    with warnings.catch_warnings():
        warnings.filterwarnings("ignore", category=ConvergenceWarning, module="sklearn")
        # Training the dataset
        mlp.fit(X_train, y_train)
    
    # printing the Batch size
    print("\nBatch size: ", b_s)
    
    # Accuracy/Score on training dataset
    print("Training set score: %f" % mlp.score(X_train, y_train))
    
    # Accuracy/Score on testing dataset
    print("Test set score: %f" % mlp.score(X_test, y_test))
    
    # plot the loss with the iteration
    plt.plot(mlp.loss_curve_)
    plt.xlabel('Iteration No')
    plt.ylabel('Loss')
    plt.show()
# Out:
# Iteration 1, loss = 1.49926633
# Iteration 2, loss = 0.75343960
# Iteration 3, loss = 0.56419144
# Iteration 4, loss = 0.48327931
# Iteration 5, loss = 0.43757988
# Iteration 6, loss = 0.40770682
# Iteration 7, loss = 0.38621088
# Iteration 8, loss = 0.37008683
# Iteration 9, loss = 0.35715709
# Iteration 10, loss = 0.34643030
#
# Batch size:  200
# Training set score: 0.903483
# Test set score: 0.910000
# Iteration 1, loss = 2.16179425
# Iteration 2, loss = 1.80651492
# Iteration 3, loss = 1.50620931
# Iteration 4, loss = 1.26204977
# Iteration 5, loss = 1.07690170
# Iteration 6, loss = 0.94161984
# Iteration 7, loss = 0.84198172
# Iteration 8, loss = 0.76701659
# Iteration 9, loss = 0.70912649
# Iteration 10, loss = 0.66339246
#
# Batch size:  1000
# Training set score: 0.847583
# Test set score: 0.853300
# Iteration 1, loss = 2.31830679
# Iteration 2, loss = 2.22640072
# Iteration 3, loss = 2.12711992
# Iteration 4, loss = 2.03443171
# Iteration 5, loss = 1.94669940
# Iteration 6, loss = 1.86267142
# Iteration 7, loss = 1.78182993
# Iteration 8, loss = 1.70378619
# Iteration 9, loss = 1.62868186
# Iteration 10, loss = 1.55660116
#
# Batch size:  5000
# Training set score: 0.681317
# Test set score: 0.683600
# Iteration 1, loss = 2.39053914
# Iteration 2, loss = 2.35513313
# Iteration 3, loss = 2.30993551
# Iteration 4, loss = 2.26447606
# Iteration 5, loss = 2.22166890
# Iteration 6, loss = 2.18128109
# Iteration 7, loss = 2.14255706
# Iteration 8, loss = 2.10464225
# Iteration 9, loss = 2.06728794
# Iteration 10, loss = 2.03025868
#
# Batch size:  10000
# Training set score: 0.427683
# Test set score: 0.421200
# Iteration 1, loss = 2.37252535
# Iteration 2, loss = 2.37059344
# Iteration 3, loss = 2.36785250
# Iteration 4, loss = 2.36439637
# Iteration 5, loss = 2.36031342
# Iteration 6, loss = 2.35568497
# Iteration 7, loss = 2.35058162
# Iteration 8, loss = 2.34507291
# Iteration 9, loss = 2.33921916
# Iteration 10, loss = 2.33307410
#
# Batch size:  60000
# Training set score: 0.091317
# Test set score: 0.092300

# %% [markdown]
# ### 6.Flipping the image

# %%
# Flip the intensities of the image for the testing and training dataset
Flip_X_train = (255 -X_train*255)/255
Flip_X_test = (255-X_test*255)/255

# %% [markdown]
# ### 7.Training and testing for flipped dataset using MLPClassifier(Multi-layer Perceptron classifier).

# %%
# make a list of different batch sizes
batch_sizes = [200, 1000, 5000, 10000, 60000]
for b_s in batch_sizes:
    # Build model using MLPClassifier
    mlp = MLPClassifier(hidden_layer_sizes=(50,),max_iter=10,
                    solver='sgd',verbose=10, batch_size=b_s)
    
    # Remove unneccessary waring
    with warnings.catch_warnings():
        warnings.filterwarnings("ignore", category=ConvergenceWarning, module="sklearn")
        # Training the dataset
        mlp.fit(Flip_X_train, y_train)
    
    # printing the Batch size
    print("\nBatch size: ", b_s)
    
    # Accuracy/Score on training dataset
    print("Fliped image training set score: %f" % mlp.score(Flip_X_train, y_train))
    
    # Accuracy/Score on testing dataset
    print("Fliped image test set score: %f" % mlp.score(Flip_X_test, y_test))
    
    # plot the loss with the iteration
    plt.plot(mlp.loss_curve_)
    plt.xlabel('Iteration No for flipped image')
    plt.ylabel('Loss')
    plt.show()
# Out:
# Iteration 1, loss = 1.59627173
# Iteration 2, loss = 0.84626770
# Iteration 3, loss = 0.61610665
# Iteration 4, loss = 0.51941395
# Iteration 5, loss = 0.46553216
# Iteration 6, loss = 0.43111395
# Iteration 7, loss = 0.40724006
# Iteration 8, loss = 0.38898388
# Iteration 9, loss = 0.37526940
# Iteration 10, loss = 0.36386235
#
# Batch size:  200
# Fliped image training set score: 0.899667
# Fliped image test set score: 0.903800
# Iteration 1, loss = 2.17410007
# Iteration 2, loss = 1.76915483
# Iteration 3, loss = 1.44888028
# Iteration 4, loss = 1.21216045
# Iteration 5, loss = 1.04460442
# Iteration 6, loss = 0.92424843
# Iteration 7, loss = 0.83479509
# Iteration 8, loss = 0.76648396
# Iteration 9, loss = 0.71296725
# Iteration 10, loss = 0.66975347
#
# Batch size:  1000
# Fliped image training set score: 0.836717
# Fliped image test set score: 0.845400
# Iteration 1, loss = 2.45300365
# Iteration 2, loss = 2.26738486
# Iteration 3, loss = 2.17747036
# Iteration 4, loss = 2.10314369
# Iteration 5, loss = 2.02370930
# Iteration 6, loss = 1.94794195
# Iteration 7, loss = 1.87076227
# Iteration 8, loss = 1.79966266
# Iteration 9, loss = 1.73258260
# Iteration 10, loss = 1.66849748
#
# Batch size:  5000
# Fliped image training set score: 0.605450
# Fliped image test set score: 0.618700
# Iteration 1, loss = 2.51834702
# Iteration 2, loss = 2.25159340
# Iteration 3, loss = 2.18546671
# Iteration 4, loss = 2.11519653
# Iteration 5, loss = 2.05219209
# Iteration 6, loss = 1.99863165
# Iteration 7, loss = 1.95006487
# Iteration 8, loss = 1.90465124
# Iteration 9, loss = 1.86201264
# Iteration 10, loss = 1.82093866
#
# Batch size:  10000
# Fliped image training set score: 0.527917
# Fliped image test set score: 0.536100
# Iteration 1, loss = 2.60346645
# Iteration 2, loss = 2.51276461
# Iteration 3, loss = 2.43046295
# Iteration 4, loss = 2.37472230
# Iteration 5, loss = 2.34634085
# Iteration 6, loss = 2.33523954
# Iteration 7, loss = 2.32979342
# Iteration 8, loss = 2.32286879
# Iteration 9, loss = 2.31236914
# Iteration 10, loss = 2.29903922
#
# Batch size:  60000
# Fliped image training set score: 0.153417
# Fliped image test set score: 0.146500

# %% [markdown]
# ### 8.Training and testing for combined flipped and unflipped dataset using MLPClassifier(Multi-layer Perceptron classifier).

# %%
import numpy as np
Combine_X_train = np.concatenate((X_train, Flip_X_train))
Combine_X_test = np.concatenate((X_test, Flip_X_test))
Combine_y_train = np.concatenate((y_train, y_train))
Combine_y_test = np.concatenate((y_test, y_test))

# %%
batch_sizes = [200, 1000, 5000, 10000, 60000]
for b_s in batch_sizes:
    # Build model using MLPClassifier
    mlp = MLPClassifier(hidden_layer_sizes=(50,),max_iter=10,
                    solver='sgd',verbose=10, batch_size=b_s)
    
    # Remove unneccessary waring
    with warnings.catch_warnings():
        warnings.filterwarnings("ignore", category=ConvergenceWarning, module="sklearn")
        # Training the dataset
        mlp.fit(Combine_X_train, Combine_y_train)
    
    # printing the Batch size
    print("\nBatch size: ", b_s)
    
    # Accuracy/Score on training dataset
    print("Combined image training set score: %f" % mlp.score(Combine_X_train, Combine_y_train))
    
    # Accuracy/Score on testing dataset
    print("Combined image test set score: %f" % mlp.score(Combine_X_test, Combine_y_test))
    
    # plot the loss with the iteration
    plt.plot(mlp.loss_curve_)
    plt.xlabel('Iteration No for Combined image')
    plt.ylabel('Loss')
    plt.show()
# Out:
# Iteration 1, loss = 1.84409751
# Iteration 2, loss = 1.06517383
# Iteration 3, loss = 0.70793316
# Iteration 4, loss = 0.55889450
# Iteration 5, loss = 0.48160634
# Iteration 6, loss = 0.43408064
# Iteration 7, loss = 0.40118030
# Iteration 8, loss = 0.37661778
# Iteration 9, loss = 0.35724507
# Iteration 10, loss = 0.34142871
#
# Batch size:  200
# Combined image training set score: 0.907333
# Combined image test set score: 0.911100
# Iteration 1, loss = 2.26218451
# Iteration 2, loss = 2.02494677
# Iteration 3, loss = 1.79798163
# Iteration 4, loss = 1.57005063
# Iteration 5, loss = 1.36652022
# Iteration 6, loss = 1.19696448
# Iteration 7, loss = 1.06063347
# Iteration 8, loss = 0.95301916
# Iteration 9, loss = 0.86833258
# Iteration 10, loss = 0.80091193
#
# Batch size:  1000
# Combined image training set score: 0.821850
# Combined image test set score: 0.830550
# Iteration 1, loss = 2.40736852
# Iteration 2, loss = 2.31435153
# Iteration 3, loss = 2.26775304
# Iteration 4, loss = 2.22389670
# Iteration 5, loss = 2.17999854
# Iteration 6, loss = 2.13634388
# Iteration 7, loss = 2.09288222
# Iteration 8, loss = 2.04883465
# Iteration 9, loss = 2.00401211
# Iteration 10, loss = 1.95841382
#
# Batch size:  5000
# Combined image training set score: 0.464225
# Combined image test set score: 0.473450
# Iteration 1, loss = 2.48038749
# Iteration 2, loss = 2.33460241
# Iteration 3, loss = 2.29543148
# Iteration 4, loss = 2.27328847
# Iteration 5, loss = 2.25597872
# Iteration 6, loss = 2.24005881
# Iteration 7, loss = 2.22391153
# Iteration 8, loss = 2.20802608
# Iteration 9, loss = 2.19267226
# Iteration 10, loss = 2.17720459
#
# Batch size:  10000
# Combined image training set score: 0.265833
# Combined image test set score: 0.272100
# Iteration 1, loss = 2.47173701
# Iteration 2, loss = 2.44264204
# Iteration 3, loss = 2.41071887
# Iteration 4, loss = 2.38269633
# Iteration 5, loss = 2.35985876
# Iteration 6, loss = 2.34188012
# Iteration 7, loss = 2.32797221
# Iteration 8, loss = 2.31732314
# Iteration 9, loss = 2.30934124
# Iteration 10, loss = 2.30338486
#
# Batch size:  60000
# Combined image training set score: 0.129125
# Combined image test set score: 0.129700
